# %%
s = "leetcode"

# %%
def firstUniqChar(s: str) -> int:
    hashMap=set()
    for i in range(len(s)):
        if s[i] not in hashMap:
            hashMap.add(s[i])
        else:
            hashMap.remove(s[i])
    for i in range(len(s)):
        if s[i] not in hashMap:
            return i
    return -1

# %%
firstUniqChar(s)
# Out:
# -1

# %%
t=[]

# %%
t[-1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\SURAVI~1\AppData\Local\Temp\1/ipykernel_13028/1057926852.py in <module>
# ----> 1 t[-1]
#
# IndexError: list index out of range
