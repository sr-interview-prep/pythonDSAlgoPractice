# %%
nums,k=[1,2,3,4,5,6,7],9
if len(nums) > k:
    nums[:]=nums[-k:]+nums[:-k]
else:
    k=k-len(nums)
    nums[:]=nums[-k:]+nums[:-k]
print(nums)
# Out:
# [6, 7, 1, 2, 3, 4, 5]

# %%
nums=[1,2,3,4,5,6,7]
nums
#  nums[:]=nums[-k:]+nums[:-k]
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
nums[-k:]+nums[:-k]
# Out:
# [5, 6, 7, 1, 2, 3, 4]

# %%
# Out:
# [1, 2, 3, 4]
